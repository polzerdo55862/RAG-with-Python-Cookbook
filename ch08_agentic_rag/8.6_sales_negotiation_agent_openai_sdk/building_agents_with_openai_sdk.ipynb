# %% [markdown]
# <h1>Chapter 8 - Agentic RAG</h1>
# <i>Building a multi-agent system using OpenAI SDK.</i>
#
# <a href="https://learning.oreilly.com/library/view/rag-with-python/9798341600553/"><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="https://github.com/polzerdo55862/RAG-with-Python-Cookbook"><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/polzerdo55862/RAG-with-Python-Cookbook/blob/main/ch08_agentic_rag/8.6_sales_negotiation_agent_openai_sdk/building_agents_with_openai_sdk.ipynb)
#
# ---
#
# This notebook is for Chapter 8 of the [RAG with Python Cookbook](https://learning.oreilly.com/library/view/rag-with-python/9798341600553/) book by [Dominik Polzer](https://www.linkedin.com/in/polzerdo/).
#
# ---
#
# <a href="https://learning.oreilly.com/library/view/rag-with-python/9798341600553/">
#   <img src="https://raw.githubusercontent.com/polzerdo55862/RAG-with-Python-Cookbook/main/rag_cookbook.png" width="350" />
# </a>

# %% [markdown]
# ## Prerequisites
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to uncomment and run the following code blocks to install the dependencies for this chapter.

# %% [markdown]
# ### Install Required Packages

# %%
# %pip install openai-agents==0.9.2 chromadb==1.5.0
# %pip install chromadb==1.5.0
# %pip install openai-agents==0.9.2
# Out:
# Requirement already satisfied: openai-agents==0.9.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (0.9.2)
# Requirement already satisfied: chromadb==1.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (1.5.0)
# Requirement already satisfied: griffe<2,>=1.5.6 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (1.15.0)
# Requirement already satisfied: mcp<2,>=1.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (1.26.0)
# Requirement already satisfied: openai<3,>=2.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.21.0)
# Requirement already satisfied: pydantic<3,>=2.12.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.12.5)
# Requirement already satisfied: requests<3,>=2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.32.3)
# Requirement already satisfied: types-requests<3,>=2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.32.4.20260107)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (4.15.0)
# Requirement already satisfied: build>=1.0.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (2.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (4.26.0)
# Requirement already satisfied: colorama>=0.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from griffe<2,>=1.5.6->openai-agents==0.9.2) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.4.3)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (0.13.0)
# Requirement already satisfied: sniffio in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2,>=1.19.0->openai-agents==0.9.2) (3.11)
# Requirement already satisfied: certifi in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==1.5.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==1.5.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==1.5.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents==0.9.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents==0.9.2) (2.41.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents==0.9.2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents==0.9.2) (2.6.3)
# Requirement already satisfied: packaging>=24.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb==1.5.0) (26.0)
# Requirement already satisfied: pyproject_hooks in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb==1.5.0) (1.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (0.10)
# Requirement already satisfied: flatbuffers in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (25.12.19)
# Requirement already satisfied: protobuf in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (6.33.5)
# Requirement already satisfied: sympy in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb==1.5.0) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==1.5.0) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.5.0) (0.60b1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.19.0->openai-agents==0.9.2) (1.0.0)
# Requirement already satisfied: cryptography>=3.4.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (2.0.0)
# Requirement already satisfied: pycparser in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==1.5.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==1.5.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.5.0) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb==1.5.0) (1.4.1)
# Requirement already satisfied: filelock in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (1.2.0)
# Requirement already satisfied: shellingham in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (1.5.4)
# Requirement already satisfied: typer-slim in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==1.5.0) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==1.5.0) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.5.0) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==1.5.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: chromadb==1.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (1.5.0)
# Requirement already satisfied: build>=1.0.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (2.4.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.24.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (7.7.0)
# Requirement already satisfied: importlib-resources in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (1.78.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from chromadb==1.5.0) (4.26.0)
# Requirement already satisfied: requests<3.0,>=2.7 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.32.3)
# Requirement already satisfied: six>=1.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb==1.5.0) (2026.1.4)
# Requirement already satisfied: packaging>=24.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb==1.5.0) (26.0)
# Requirement already satisfied: pyproject_hooks in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from build>=1.0.3->chromadb==1.5.0) (1.2.0)
# Requirement already satisfied: anyio in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==1.5.0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb==1.5.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==1.5.0) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb==1.5.0) (0.30.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb==1.5.0) (0.10)
# Requirement already satisfied: flatbuffers in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (25.12.19)
# Requirement already satisfied: protobuf in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (6.33.5)
# Requirement already satisfied: sympy in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.0) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb==1.5.0) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==1.5.0) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.0) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.5.0) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==1.5.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==1.5.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic>=1.9->chromadb==1.5.0) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==1.5.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from rich>=10.11.0->chromadb==1.5.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.5.0) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb==1.5.0) (1.4.1)
# Requirement already satisfied: filelock in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (1.2.0)
# Requirement already satisfied: shellingham in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (1.5.4)
# Requirement already satisfied: typer-slim in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.0) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==1.5.0) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from typer>=0.9.0->chromadb==1.5.0) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (1.0.0)
# Requirement already satisfied: uvloop>=0.15.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.0) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.5.0) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==1.5.0) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai-agents==0.9.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (0.9.2)
# Requirement already satisfied: griffe<2,>=1.5.6 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (1.15.0)
# Requirement already satisfied: mcp<2,>=1.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (1.26.0)
# Requirement already satisfied: openai<3,>=2.19.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.21.0)
# Requirement already satisfied: pydantic<3,>=2.12.3 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.12.5)
# Requirement already satisfied: requests<3,>=2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.32.3)
# Requirement already satisfied: types-requests<3,>=2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (2.32.4.20260107)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai-agents==0.9.2) (4.15.0)
# Requirement already satisfied: colorama>=0.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from griffe<2,>=1.5.6->openai-agents==0.9.2) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (4.12.1)
# Requirement already satisfied: httpx-sse>=0.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (4.26.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (2.13.1)
# Requirement already satisfied: pyjwt>=2.10.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from mcp<2,>=1.19.0->openai-agents==0.9.2) (0.41.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (0.13.0)
# Requirement already satisfied: sniffio in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from openai<3,>=2.19.0->openai-agents==0.9.2) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2,>=1.19.0->openai-agents==0.9.2) (3.11)
# Requirement already satisfied: certifi in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents==0.9.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic<3,>=2.12.3->openai-agents==0.9.2) (2.41.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents==0.9.2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from requests<3,>=2.0->openai-agents==0.9.2) (2.6.3)
# Requirement already satisfied: attrs>=22.2.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents==0.9.2) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents==0.9.2) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents==0.9.2) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.19.0->openai-agents==0.9.2) (0.30.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.19.0->openai-agents==0.9.2) (1.0.0)
# Requirement already satisfied: cryptography>=3.4.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (2.0.0)
# Requirement already satisfied: pycparser in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (3.0)
# Requirement already satisfied: click>=7.0 in /workspaces/RAG-with-Python-Cookbook/.venv/lib/python3.12/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.19.0->openai-agents==0.9.2) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Load secrets
#
# If you run this code in Google Colab, save your OpenAI API key in the secrets and access it by

# %%
import os
import sys
from dotenv import load_dotenv

# Check if running in Google Colab
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    try:
        from google.colab import userdata  # type: ignore

        os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
    except ModuleNotFoundError:
        pass
else:
    load_dotenv()

# %% [markdown]
# ### Load sample files
#
# This notebook uses sample Word and PDF files.
#
# When running the notebook on Google Colab, uncomment the code below to download the `datasets` directory from the GitHub repo.

# %%
import sys

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !git clone --no-checkout https://github.com/polzerdo55862/RAG-with-Python-Cookbook.git
    # %cd RAG-with-Python-Cookbook
    # !git sparse-checkout init --cone
    # !git sparse-checkout set datasets
    # !git checkout
    # !cp -r datasets /content/datasets
    print("\u2713 Datasets downloaded to /content/datasets")

    # set the datasets_dir
    datasets_dir = "./datasets"
else:
    datasets_dir = "../../datasets"
    print("\u26a0 Running locally. Using ../datasets/ directory")
# Out:
# ⚠ Running locally. Using ../datasets/ directory

# %% [markdown]
# ## Multi-Agent System Implementation

# %%
import os
import shutil
import chromadb
from chromadb.config import Settings

def fill_chroma_db():
    chroma_dir = "./chroma_email_history_db"
    # If the directory exists, remove it to overwrite
    if os.path.exists(chroma_dir):
        shutil.rmtree(chroma_dir)
    client = chromadb.Client(Settings(persist_directory=chroma_dir))
    collection = client.get_or_create_collection("email_history")

    with open(f'{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt', "r", encoding="utf-8") as f:
        email_text = f.read()

    email_docs = [
        e.strip() for e in email_text.split("\n---\n") if e.strip()
    ]

    for idx, doc in enumerate(email_docs):
        collection.add(documents=[doc], ids=[f"email_{idx+1}"])
        print(f"Added email_{idx+1}")

fill_chroma_db()
# Out:
# 2026-02-24 21:34:37.064846774 [W:onnxruntime:Default, device_discovery.cc:131 GetPciBusId] Skipping pci_bus_id for PCI path at "/sys/devices/LNXSYSTM:00/LNXSYBUS:00/PNP0A03:00/device:07/VMBUS:01/5620e0c7-8062-4dce-aeb7-520c7ef76171" because filename ""5620e0c7-8062-4dce-aeb7-520c7ef76171"" dit not match expected pattern of [0-9a-f]+:[0-9a-f]+:[0-9a-f]+[.][0-9a-f]+
# Added email_1

# %%
import chromadb
from chromadb.config import Settings
from agents import function_tool

@function_tool
def query_database(query_text, n_results=3):
    """
    Query emails using semantic search from a local ChromaDB collection.
    """

    # Set up ChromaDB client and collection
    chroma_dir = "./chroma_email_history_db"
    client = chromadb.Client(Settings(persist_directory=chroma_dir))
    collection = client.get_or_create_collection("email_history")

    # Perform the query
    results = collection.query(
        query_texts=[query_text],
        n_results=n_results,
        include=["documents"],
    )
    return {
        "query": query_text,
        "documents": (
            results["documents"][0] if results["documents"] else []
        ),
    }

# %%
from agents import Agent, Runner
from agents import trace

# Create a negotiation agent with email search capability
salesman_agent = Agent(
    name="Negotiation Agent",
    instructions="""You are a skilled negotiation agent
    representing a salesperson.

    Your role:
    - Analyze the current email conversation history
    - Search for relevant information using the query_database tool
    - Generate informed responses with strategic counter-offers

    Process:
    1. Use query_database to find relevant context from email history
    2. Analyze customer concerns and pricing constraints
    3. Craft a professional response with a competitive counter-offer
    4. Maintain a collaborative tone while protecting profit margins
    """,
    tools=[query_database],
    model="gpt-5"
)

# Helper function to run the negotiation agent
async def negotiate_with_customer(email_history):
    with trace("Negotiation Response"):
        result = await Runner.run(
            salesman_agent,
            f"Email conversation history:\n{email_history}"
        )
    return result.final_output

# %%
from agents import Agent, Runner

async def run_negotiation_process():
    """
    Orchestrates a negotiation between customer and salesperson agents
    using a moderator agent to facilitate the conversation.
    """
    # Load the email history from file
    with open(f'{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt', "r", encoding="utf-8") as f:
        email_history = f.read()

    # Define the customer agent
    customer_agent = Agent(
        name="Customer",
        instructions="""Negotiate for the best laptop deal.
                       Be polite but persistent.
                       Respond to the email chain below.""",
        model="gpt-5-mini",
    )

    # Convert agents to tools for the moderator
    customer_agent_tool = customer_agent.as_tool(
        tool_name="customer",
        tool_description=(
            "Tool that represents the customer in negotiations."
        )
    )

    salesman_agent_tool = salesman_agent.as_tool(
        tool_name="salesman",
        tool_description=(
            "Tool that represents the salesperson in negotiations."
        )
    )

    # Define the moderator agent with clear instructions
    moderator_instructions = """
    You are a moderator facilitating negotiation between
    customer and salesperson.

    Process:
    1. Receive email history with the last message from customer
    2. Use salesman_agent_tool to generate salesperson response
    3. Append response to email history
    4. Use customer_agent_tool to generate customer response
    5. Continue alternating until agreement or breakdown

    Rules:
    - Aim for mutually beneficial agreement
    """

    moderator_agent = Agent(
        name="Moderator",
        instructions=moderator_instructions,
        model="gpt-5-mini",
        tools=[customer_agent_tool, salesman_agent_tool]
    )

    # Execute the negotiation with tracing
    with trace("Negotiation Process"):
        responses = await Runner.run(
            moderator_agent,
            f"Begin negotiation with this email history: {email_history}"
        )

    return responses

# %%
import os
import shutil
import chromadb
from chromadb.config import Settings

def fill_chroma_db():
    chroma_dir = "./chroma_email_history_db"
    # If the directory exists, remove it to overwrite
    if os.path.exists(chroma_dir):
        shutil.rmtree(chroma_dir)
    client = chromadb.Client(Settings(persist_directory=chroma_dir))
    collection = client.get_or_create_collection("email_history")

    with open(f"{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt", "r", encoding="utf-8") as f:
        email_text = f.read()

    email_docs = [e.strip() for e in email_text.split("\n---\n") if e.strip()]

    for idx, doc in enumerate(email_docs):
        collection.add(documents=[doc], ids=[f"email_{idx+1}"])
        print(f"Added email_{idx+1}")

fill_chroma_db()
# Out:
# Added email_1

# %%
import chromadb
from chromadb.config import Settings

@function_tool
def query_database(query_text: str, n_results: int = 3) -> dict:
    """
    Query emails using semantic search from a local ChromaDB collection.
    """

    # Set up ChromaDB client and collection
    chroma_dir = "./chroma_email_history_db"
    client = chromadb.Client(Settings(persist_directory=chroma_dir))
    collection = client.get_or_create_collection("email_history")

    # Perform the query
    results = collection.query(
        query_texts=[query_text],
        n_results=n_results,
        include=["documents"],
    )
    return {
        "query": query_text,
        "documents": results["documents"][0] if results["documents"] else [],
    }

# %%
from agents import Agent, Runner
from agents import trace

# Create a negotiation agent with email search capability
salesman_agent = Agent(
    name="Negotiation Agent",
    instructions="""You are a skilled negotiation agent representing a salesperson.

    Your role:
    - Analyze the current email conversation history
    - Search for relevant information using the query_database tool
    - Generate informed responses with strategic counter-offers

    Process:
    1. Use query_database to find relevant context from email history
    2. Analyze customer concerns and pricing constraints
    3. Craft a professional response with a competitive counter-offer
    4. Maintain a collaborative tone while protecting profit margins
    """,
    tools=[query_database],
    model="gpt-5"
)

# Helper function to run the negotiation agent
async def negotiate_with_customer(email_history: str) -> str:
    with trace("Negotiation Response"):
        result = await Runner.run(
            salesman_agent,
            f"Email conversation history:\n{email_history}"
        )
    return result.final_output

# %%
from agents import trace

async def demonstrate_negotiation():
    with open(f"{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt",
              "r", encoding="utf-8") as f:
        email_history = f.read()

    # Generate negotiation response using the agent
    with trace("Automated Customer Response"):
        response = await negotiate_with_customer(email_history)

    print(response)
    return response

await demonstrate_negotiation()
# Out:
# Trace already exists. Creating a new trace, but this is probably a mistake.
# I wasn’t able to retrieve the email thread (database returned “404: Not Found”). If you can share the last inbound email and a few details (budget cap, current quote/term, seat count, renewal date, any competitor mentioned), I’ll tailor this precisely. In the meantime, here’s a ready-to-send response with strategic counter-offers you can tweak.
#
# Subject: Let’s align on a plan that fits your budget and timeline
#
# Hi [First Name],
#
# Thanks for the candid feedback on pricing. I want to make sure we protect the outcomes we discussed—[key outcomes/use cases]—while keeping this within your budget and timeline. Based on what you shared, here are two paths that balance cost and value:
#
# Option A — Lean and simple (1-year):
# - Price: $[X]/yr with a 7–8% concession
# - Onboarding: 50% off implementation (or swap for [2] training sessions)
# - Terms: Net 30, with a 12-month price lock
#
# Option B — Best total value (2-year):
# - Price: $[X]/yr with a 12% concession (annual prepay)
# - Adds: +10% additional seats or 2 premium support incidents, plus a 24-month price lock
# - We can extend Net 45 if procurement needs it
#
# If your budget cap is firm at $[cap], we can also phase the rollout:
# - Phase 1 now: [N] seats at $[price]
# - Phase 2 in Q[ ], same rate held for 90 days
#
# If you’re comparing alternatives, I’m happy to review the quote details (seats, term, services) and make sure we’re apples-to-apples. Where it makes sense, we can meet the effective total cost through term, scope, or value-adds rather than deep discounts.
#
# If we can align on Option A or B and an LOI by [Day, Date], I can secure this pricing and hold it through [expiry date].
#
# Would either option work for you? I can jump on a quick 15-minute call [Day, time window] or [Day, time window] to finalize.
#
# Best regards,
# [Your Name]
# [Title]
# [Phone] | [Email]
#
# Notes for you (pick and adjust before sending):
# - Protect margins: keep single-year discount ≤8%; reserve 12% for 2-year with annual prepay. If you must go deeper, trade for a longer term, volume increase, or a reference/case study.
# - Value > discount: leading alternatives to pure discount are onboarding reduction, training credits, limited priority support, or +10% seats—these preserve margin.
# - Give-to-get: tie any concession to (a) signature/LOI by a date, (b) multi-year or prepay, (c) expanded scope, or (d) reference/case study.
# - Competitive pressure: if they present a lower quote, ask for details; match on effective TCO only with a commitment date and term.
#
# Share the last email and numbers when you can, and I’ll refine this into a precise counter.
# 'I wasn’t able to retrieve the email thread (database returned “404: Not Found”). If you can share the last inbound email and a few details (budget cap, current quote/term, seat count, renewal date, any competitor mentioned), I’ll tailor this precisely. In the meantime, here’s a ready-to-send response with strategic counter-offers you can tweak.\n\nSubject: Let’s align on a plan that fits your budget and timeline\n\nHi [First Name],\n\nThanks for the candid feedback on pricing. I want to make sure we protect the outcomes we discussed—[key outcomes/use cases]—while keeping this within your budget and timeline. Based on what you shared, here are two paths that balance cost and value:\n\nOption A — Lean and simple (1-year):\n- Price: $[X]/yr with a 7–8% concession\n- Onboarding: 50% off implementation (or swap for [2] training sessions)\n- Terms: Net 30, with a 12-month price lock\n\nOption B — Best total value (2-year):\n- Price: $[X]/yr with a 12% concession (annual prepay)\n- Adds: +10% additional seats or 2 premium support incidents, plus a 24-month price lock\n- We can extend Net 45 if procurement needs it\n\nIf your budget cap is firm at $[cap], we can also phase the rollout:\n- Phase 1 now: [N] seats at $[price]\n- Phase 2 in Q[ ], same rate held for 90 days\n\nIf you’re comparing alternatives, I’m happy to review the quote details (seats, term, services) and make sure we’re apples-to-apples. Where it makes sense, we can meet the effective total cost through term, scope, or value-adds rather than deep discounts.\n\nIf we can align on Option A or B and an LOI by [Day, Date], I can secure this pricing and hold it through [expiry date].\n\nWould either option work for you? I can jump on a quick 15-minute call [Day, time window] or [Day, time window] to finalize.\n\nBest regards,\n[Your Name]\n[Title]\n[Phone] | [Email]\n\nNotes for you (pick and adjust before sending):\n- Protect margins: keep single-year discount ≤8%; reserve 12% for 2-year with annual prepay. If you must go deeper, trade for a longer term, volume increase, or a reference/case study.\n- Value > discount: leading alternatives to pure discount are onboarding reduction, training credits, limited priority support, or +10% seats—these preserve margin.\n- Give-to-get: tie any concession to (a) signature/LOI by a date, (b) multi-year or prepay, (c) expanded scope, or (d) reference/case study.\n- Competitive pressure: if they present a lower quote, ask for details; match on effective TCO only with a commitment date and term.\n\nShare the last email and numbers when you can, and I’ll refine this into a precise counter.'

# %%
with open(f"{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt", "r", encoding="utf-8") as f:
    email_history = f.read()

email_history
# Out:
# '404: Not Found'

# %%
from agents import Agent, Runner

async def run_negotiation_process():
    """
    Orchestrates a negotiation between customer and salesperson agents
    using a moderator agent to facilitate the conversation.
    """
    # Load the email history from file
    with open(f"{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt", "r", encoding="utf-8") as f:
        email_history = f.read()

    # Define the customer agent
    customer_agent = Agent(
        name="Customer",
        instructions="""Negotiate for the best laptop deal.
                       Be polite but persistent.
                       Respond to the email chain below.""",
        model="gpt-5-mini",
    )

    # Convert agents to tools for the moderator
    customer_agent_tool = customer_agent.as_tool(
        tool_name="customer",
        tool_description="Tool that represents the customer in negotiations."
    )

    salesman_agent_tool = salesman_agent.as_tool(
        tool_name="salesman",
        tool_description="Tool that represents the salesperson in negotiations."
    )

    # Define the moderator agent with clear instructions
    moderator_instructions = """
    You are a moderator facilitating negotiation between customer and salesperson.

    Process:
    1. Receive email history with the last message from customer
    2. Use salesman_agent_tool to generate salesperson response
    3. Append response to email history
    4. Use customer_agent_tool to generate customer response
    5. Continue alternating until agreement or breakdown

    Rules:
    - Aim for mutually beneficial agreement
    """

    moderator_agent = Agent(
        name="Moderator",
        instructions=moderator_instructions,
        model="gpt-5-mini",
        tools=[customer_agent_tool, salesman_agent_tool]
    )

    # Execute the negotiation with tracing
    with trace("Negotiation Process"):
        responses = await Runner.run(
            moderator_agent,
            f"Begin negotiation with this email history: {email_history}"
        )

    return responses

# %%
responses = await run_negotiation_process()

# %%
from agents import Agent, Runner

async def run_negotiation_process_with_handoffs():
    """
    Direct negotiation between customer and salesperson agents
    using handoffs to alternate between them.
    """
    # Load the email history from file
    with open(f"{datasets_dir}/sample_data_negotiation_agents/sample_email_history.txt", "r", encoding="utf-8") as f:
        email_history = f.read()

    # Define the salesperson agent
    salesman_agent = Agent(
        name="Salesperson",
        instructions="""You are a laptop salesperson negotiating a deal.
                       Make reasonable offers and try to close the sale.
                       If you reach agreement, clearly state 'DEAL AGREED'.
                       If negotiation isn't working after 3 rounds, politely end it.""",
        model="gpt-5-mini",
        handoff_description="Hand off to customer for their response to your offer."
    )

    # Define the customer agent with handoff capabilities
    customer_agent = Agent(
        name="Customer",
        instructions="""Negotiate for the best laptop deal.
                       Be polite but persistent.
                       Make counteroffers or accept good deals.
                       If you accept a deal, clearly state 'DEAL ACCEPTED'.
                       If you can't reach agreement after 3 rounds, politely walk away.""",
        model="gpt-5-mini",
        handoff_description="Hand off to salesperson for their response to your counteroffer."
    )

    # Convert each agent to a tool for the other
    customer_tool = customer_agent.as_tool(
        tool_name="handoff_to_customer",
        tool_description="Hand the conversation to the customer agent."
    )

    salesman_tool = salesman_agent.as_tool(
        tool_name="handoff_to_salesperson",
        tool_description="Hand the conversation to the salesperson agent."
    )

    # Give each agent the ability to hand off to the other
    customer_agent.tools = [salesman_tool]
    salesman_agent.tools = [customer_tool]

    # Start with the salesperson responding to the email history
    with trace("Direct Negotiation Process"):
        responses = await Runner.run(
            salesman_agent,
            f"Respond to this email history and begin negotiation: {email_history}"
        )

    return responses

# %%
responses = await run_negotiation_process_with_handoffs()
